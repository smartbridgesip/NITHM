# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lakshmi Sravya\\Desktop\\datasets\\datasets1'

# %%
os.chdir('C:/Users/Lakshmi Sravya/Desktop/datasets/datasets1')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lakshmi Sravya\\Desktop\\datasets\\datasets1'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
crypto_data=pd.read_csv("coinmarketcap_06012018.csv")

# %%
crypto_data
# Out:
#     Unnamed: 0  24h_volume_usd  available_supply                    id  \
# 0            0     22081300000          16785225               bitcoin
# 1            1      5221370000       38739144847                ripple
# 2            2      5705690000          96803840              ethereum
# 3            3      1569900000          16896225          bitcoin-cash
# 4            4       428305000       25927070538               cardano
# 5            5      2105240000          54637708              litecoin
# 6            6       146039000        8999999999                   nem
# 7            7       656389000       17877794558               stellar
# 8            8      2971610000       65748192475                  tron
# 9            9       194039000        2779530283                  iota
# 10          10       238654000           7801457                  dash
# 11          11       259097000          65000000                   neo
# ...

# %%
crypto_data=crypto_data.drop(['max_supply'],axis=1)
crypto_data
# Out:
#     Unnamed: 0  24h_volume_usd  available_supply                    id  \
# 0            0     22081300000          16785225               bitcoin
# 1            1      5221370000       38739144847                ripple
# 2            2      5705690000          96803840              ethereum
# 3            3      1569900000          16896225          bitcoin-cash
# 4            4       428305000       25927070538               cardano
# 5            5      2105240000          54637708              litecoin
# 6            6       146039000        8999999999                   nem
# 7            7       656389000       17877794558               stellar
# 8            8      2971610000       65748192475                  tron
# 9            9       194039000        2779530283                  iota
# 10          10       238654000           7801457                  dash
# 11          11       259097000          65000000                   neo
# ...

# %%
crypto_data.columns
# Out:
# Index(['Unnamed: 0', '24h_volume_usd', 'available_supply', 'id',
#        'last_updated', 'market_cap_usd', 'name', 'percent_change_1h',
#        'percent_change_24h', 'percent_change_7d', 'price_btc', 'price_usd',
#        'rank', 'symbol', 'total_supply'],
#       dtype='object')

# %%
crypto_data=crypto_data.drop(['Unnamed: 0'],axis=1)
crypto_data
# Out:
#     24h_volume_usd  available_supply                    id  last_updated  \
# 0      22081300000          16785225               bitcoin    1515230661
# 1       5221370000       38739144847                ripple    1515230641
# 2       5705690000          96803840              ethereum    1515230649
# 3       1569900000          16896225          bitcoin-cash    1515230652
# 4        428305000       25927070538               cardano    1515230654
# 5       2105240000          54637708              litecoin    1515230641
# 6        146039000        8999999999                   nem    1515230644
# 7        656389000       17877794558               stellar    1515230643
# 8       2971610000       65748192475                  tron    1515230654
# 9        194039000        2779530283                  iota    1515230652
# 10       238654000           7801457                  dash    1515230641
# 11       259097000          65000000                   neo    1515230647
# ...

# %%
crypto_data=crypto_data.drop(['id'],axis=1)
crypto_data
# Out:
#     24h_volume_usd  available_supply  last_updated  market_cap_usd  \
# 0      22081300000          16785225    1515230661    284909052105
# 1       5221370000       38739144847    1515230641    119207709132
# 2       5705690000          96803840    1515230649    100115499075
# 3       1569900000          16896225    1515230652     44424061657
# 4        428305000       25927070538    1515230654     25916647856
# 5       2105240000          54637708    1515230641     16574020942
# 6        146039000        8999999999    1515230644     14813369998
# 7        656389000       17877794558    1515230643     12634630726
# 8       2971610000       65748192475    1515230654     11741640953
# 9        194039000        2779530283    1515230652     11143859582
# 10       238654000           7801457    1515230641      9443273049
# 11       259097000          65000000    1515230647      6409507000
# 12       647694000         586635743    1515230651      6378431775
# ...

# %%
crypto_data=crypto_data.drop(['symbol'],axis=1)
crypto_data
# Out:
#     24h_volume_usd  available_supply  last_updated  market_cap_usd  \
# 0      22081300000          16785225    1515230661    284909052105
# 1       5221370000       38739144847    1515230641    119207709132
# 2       5705690000          96803840    1515230649    100115499075
# 3       1569900000          16896225    1515230652     44424061657
# 4        428305000       25927070538    1515230654     25916647856
# 5       2105240000          54637708    1515230641     16574020942
# 6        146039000        8999999999    1515230644     14813369998
# 7        656389000       17877794558    1515230643     12634630726
# 8       2971610000       65748192475    1515230654     11741640953
# 9        194039000        2779530283    1515230652     11143859582
# 10       238654000           7801457    1515230641      9443273049
# 11       259097000          65000000    1515230647      6409507000
# 12       647694000         586635743    1515230651      6378431775
# ...

# %%
crypto_data.columns
# Out:
# Index(['24h_volume_usd', 'available_supply', 'last_updated', 'market_cap_usd',
#        'name', 'percent_change_1h', 'percent_change_24h', 'percent_change_7d',
#        'price_btc', 'price_usd', 'rank', 'total_supply'],
#       dtype='object')

# %%
crypto_data.describe()
# Out:
#        24h_volume_usd  available_supply  last_updated  market_cap_usd  \
# count    1.000000e+02      1.000000e+02  1.000000e+02    1.000000e+02
# mean     5.313066e+08      4.397534e+10  1.515231e+09    7.608243e+09
# std      2.354403e+09      2.636906e+11  5.135920e+00    3.234455e+10
# min      3.895190e+05      6.452220e+05  1.515231e+09    2.995155e+08
# 25%      1.983332e+07      5.478988e+07  1.515231e+09    4.613692e+08
# 50%      4.442795e+07      2.045273e+08  1.515231e+09    7.297321e+08
# 75%      1.713828e+08      1.502973e+09  1.515231e+09    1.980319e+09
# max      2.208130e+10      2.509984e+12  1.515231e+09    2.849091e+11
#
#        percent_change_1h  percent_change_24h  percent_change_7d     price_btc  \
# count         100.000000          100.000000          100.00000  1.000000e+02
# mean            0.051700           11.169200          112.12080  1.605252e-02
# std             2.592407           34.088136          228.17529  1.013187e-01
# ...

# %%
crypto_data.cov()
# Out:
#                     24h_volume_usd  available_supply  last_updated  \
# 24h_volume_usd        5.543211e+18     -1.726650e+19  1.716142e+09
# available_supply     -1.726650e+19      6.953273e+22 -1.007029e+11
# last_updated          1.716142e+09     -1.007029e+11  2.637768e+01
# market_cap_usd        7.348602e+19     -2.369458e+20  1.858979e+10
# percent_change_1h    -1.104690e+08     -1.835483e+10  2.354973e+00
# percent_change_24h   -3.491587e+09      6.229696e+12 -8.115103e+00
# percent_change_7d    -2.804893e+10      5.417864e+13  3.911854e+01
# price_btc             2.213924e+08     -7.125855e+08  1.035509e-01
# price_usd             3.756270e+12     -1.197956e+13  1.761737e+03
# rank                 -2.202960e+10      1.396613e+11  3.453030e+01
# total_supply         -7.517352e+19      1.628836e+23  3.832263e+11
#
#                     market_cap_usd  percent_change_1h  percent_change_24h  \
# 24h_volume_usd        7.348602e+19      -1.104690e+08       -3.491587e+09
# ...

# %%
crypto_data.corr()
# Out:
#                     24h_volume_usd  available_supply  last_updated  \
# 24h_volume_usd            1.000000         -0.027812      0.141923
# available_supply         -0.027812          1.000000     -0.074358
# last_updated              0.141923         -0.074358      1.000000
# market_cap_usd            0.964990         -0.027781      0.111906
# percent_change_1h        -0.018099         -0.026851      0.176874
# percent_change_24h       -0.043505          0.693057     -0.046352
# percent_change_7d        -0.052212          0.900461      0.033381
# price_btc                 0.928095         -0.026672      0.198997
# price_usd                 0.928439         -0.026438      0.199618
# rank                     -0.322519          0.018256      0.231746
# total_supply             -0.029950          0.579422      0.069992
#
#                     market_cap_usd  percent_change_1h  percent_change_24h  \
# 24h_volume_usd            0.964990          -0.018099           -0.043505
# ...

# %%
crypto_data.dtypes
# Out:
# 24h_volume_usd          int64
# available_supply        int64
# last_updated            int64
# market_cap_usd          int64
# name                   object
# percent_change_1h     float64
# percent_change_24h    float64
# percent_change_7d     float64
# price_btc             float64
# price_usd             float64
# rank                    int64
# total_supply            int64
# dtype: object

# %%
crypto_data.boxplot(column='market_cap_usd',by='24h_volume_usd')

# %%
crypto_data['total_supply'].hist(bins=10)

# %%
crypto_data['market_cap_usd'].hist(bins=10)

# %%
import seaborn as sns
sns.pairplot(crypto_data)

# %%
total_supply=crypto_data['total_supply']

# %%
available_supply=crypto_data['available_supply']

# %%
price_usd=crypto_data['price_usd']
price_btc=crypto_data['price_btc']
volume_usd=crypto_data['24h_volume_usd']

# %%
mean_total_supply=crypto_data['total_supply'].mean()
mean_total_supply
# Out:
# 164067878642.99

# %%
import seaborn as sns
plt.plot(price_usd,total_supply,'o')
plt.ylabel("total_supply")
plt.xlabel("price_usd")
plt.axhline(mean_total_supply, color='r', linestyle='-')
sns.regplot(x='price_usd', y='total_supply', data=crypto_data)

# %%
import seaborn as sns
plt.plot(price_usd,total_supply,'o')
plt.ylabel("total_supply")
plt.xlabel("price_btc")
plt.axhline(mean_total_supply, color='r', linestyle='-')
sns.regplot(x='price_btc', y='total_supply', data=crypto_data)

# %%
plt.plot(volume_usd,total_supply,'o')
plt.ylabel("total_supply")
plt.xlabel("volume_used")
plt.axhline(mean_total_supply, color='r', linestyle='-')
sns.regplot(x='24h_volume_usd', y='total_supply', data=crypto_data)

# %%
plt.plot(available_supply,total_supply,'o')
plt.ylabel("total_supply")
plt.xlabel("available_supply")
plt.axhline(mean_total_supply, color='r', linestyle='-')
sns.regplot(x='available_supply', y='total_supply', data=crypto_data)

# %%
sns.distplot(crypto_data['available_supply'])

# %%
import seaborn as sns
corr=crypto_data.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
import statsmodels.api as sm
model1=sm.OLS(total_supply,available_supply).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           total_supply   R-squared:               -11968301.774
# Model:                            OLS   Adj. R-squared:          -12089193.721
# Method:                 Least Squares   F-statistic:                    -99.00
# Date:                Fri, 21 Jun 2019   Prob (F-statistic):               1.00
# Time:                        16:06:58   Log-Likelihood:                -2890.7
# No. Observations:                 100   AIC:                             5783.
# Df Residuals:                      99   BIC:                             5786.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
x=available_supply
y=total_supply

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=1)

# %%
x_train
# Out:
# 86         99788314
# 53        640788433
# 77         60522871
# 15         73787268
# 83     325190215376
# 41         91043076
# 45        238421940
# 91       1607622325
# 26          2996331
# 98        756192535
# 43     210087515465
# 55         54507718
# 24       2606720000
# 4       25927070538
# 58        360482334
# 49         97981284
# 21        378545005
# 87        226091449
# 3          16896225
# 74        182963195
# 30     112648430726
# 66           645222
# 70        250000000
# 42        834262000
# 47          2036645
# 89        530051126
# 8       65748192475
# 60       6885695758
# 0          16785225
# 90        342699966
# 57        350000000
# 22      14505501607
# 61    2509983876433
# 63        478550801
# 7       17877794558
# 96         50148936
# 13         15569135
# 68          8745102
# 85        104661310
# 14         16748174
# 29         98689749
# 28        998999495
# 11         65000000
# 18        116710388
# 20      31396146174
# ...

# %%
x_train=x_train.values.reshape((-1,1))

# %%
x_train
# Out:
# array([[     99788314],
#        [    640788433],
#        [     60522871],
#        [     73787268],
#        [ 325190215376],
#        [     91043076],
#        [    238421940],
#        [   1607622325],
#        [      2996331],
#        [    756192535],
#        [ 210087515465],
#        [     54507718],
#        [   2606720000],
#        [  25927070538],
#        [    360482334],
#        [     97981284],
#        [    378545005],
#        [    226091449],
#        [     16896225],
#        [    182963195],
#        [ 112648430726],
#        [       645222],
#        [    250000000],
#        [    834262000],
#        [      2036645],
#        [    530051126],
#        [  65748192475],
#        [   6885695758],
#        [     16785225],
#        [    342699966],
#        [    350000000],
#        [  14505501607],
#        [2509983876433],
#        [    478550801],
#        [  17877794558],
#        [     50148936],
#        [     15569135],
#        [      8745102],
# ...

# %%
y_train=y_train.values.reshape((-1,1))

# %%
y_train
# Out:
# array([[     99788314],
#        [    999999999],
#        [     83337000],
#        [    100287268],
#        [1841395638392],
#        [    181043076],
#        [    433494437],
#        [   5541877892],
#        [      2996331],
#        [   1000000000],
#        [ 245119283121],
#        [    120000000],
#        [   2606720000],
#        [  31112483745],
#        [   1000000000],
#        [    129231284],
#        [    400230000],
#        [    352000000],
#        [     16896225],
#        [    870663574],
#        [ 112648430726],
#        [      1000000],
#        [    260000000],
#        [   1000000000],
#        [    100000000],
#        [    530051126],
#        [ 100000000000],
#        [   6885695758],
#        [     16785225],
#        [   1000000000],
#        [   1000000000],
#        [  14505501607],
#        [3415497326789],
#        [   1000000000],
#        [ 103570548975],
#        [    100000000],
#        [     15569135],
#        [      8745102],
# ...

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x_train,y_train)

# %%
accuracy=model.score(x_train,y_train)

# %%
accuracy
# Out:
# 0.8685078506829149

# %%
x_test=x_test.values.reshape((-1,1))

# %%
x_test
# Out:
# array([[  2429624141],
#        [     3821472],
#        [  1468089837],
#        [     9137582],
#        [    40510000],
#        [    98914249],
#        [   100000000],
#        [     1288862],
#        [   233020472],
#        [    61299856],
#        [     2000000],
#        [    42462792],
#        [ 28713325229],
#        [    75401962],
#        [  4249873622],
#        [    37004027],
#        [    99014000],
#        [    11000000],
#        [   492954537],
#        [     7801457],
#        [    96803840],
#        [   134132697],
#        [    64355352],
#        [    55284715],
#        [183253534612],
#        [  9656878003],
#        [    24898178],
#        [  3470483788],
#        [    54840598],
#        [756097560976],
#        [   998999942],
#        [    40772871],
#        [  4997507466],
#        [   617314171],
#        [   350000000],
#        [   103903777],
#        [ 10614760961],
#        [  1000000000],
#        [     6168154],
# ...

# %%
predictions=model.predict(x_test)

# %%
y_pred=model.intercept_+model.coef_*x_test

# %%
y_pred
# Out:
# array([[2.40416842e+10],
#        [2.06000219e+10],
#        [2.26774857e+10],
#        [2.06075642e+10],
#        [2.06520745e+10],
#        [2.07349369e+10],
#        [2.07364773e+10],
#        [2.05964287e+10],
#        [2.09252031e+10],
#        [2.06815706e+10],
#        [2.05974376e+10],
#        [2.06548451e+10],
#        [6.13322791e+10],
#        [2.07015783e+10],
#        [2.66242043e+10],
#        [2.06471004e+10],
#        [2.07350784e+10],
#        [2.06102066e+10],
#        [2.12939905e+10],
#        [2.06056686e+10],
#        [2.07319427e+10],
#        [2.07849039e+10],
#        [2.06859057e+10],
#        [2.06730365e+10],
#        [2.80589693e+11],
#        [3.42955140e+10],
#        [2.06299249e+10],
#        [2.55184274e+10],
#        [2.06724064e+10],
#        [1.09332510e+12],
#        [2.20119538e+10],
#        [2.06524475e+10],
#        [2.76849267e+10],
#        [2.14704285e+10],
#        [2.10911705e+10],
#        [2.07420159e+10],
#        [3.56545321e+10],
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score
y_train_prediction = model.predict(x_train)
y_test_prediction = model.predict(x_test)

# %%
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")
rmse_training = (np.sqrt(mean_squared_error(y_train, y_train_prediction)))
r2_training = r2_score(y_train, y_train_prediction)
print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse_training))
print('R2 score is {}'.format(r2_training))
print("\n")
rmse_testing = (np.sqrt(mean_squared_error(y_test, y_test_prediction)))
r2_testing = r2_score(y_test, y_test_prediction)
print("The model performance for testing set")
print("--------------------------------------")
print('Root mean squared error: ', rmse_testing)
print('R2 score: ', r2_testing)
# Out:
# Slope: [[1.4187726]]
# Intercept: [2.05946001e+10]
#
#
# The model performance for training set
# --------------------------------------
# RMSE is 178592473614.2815
# R2 score is 0.8685078506829149
#
#
# The model performance for testing set
# --------------------------------------
# Root mean squared error:  1408532444846.7952
# R2 score:  0.18488695764582852

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.45,random_state=1)

# %%
x_train=x_train.values.reshape((-1,1))
y_train=y_train.values.reshape((-1,1))
x_test=x_test.values.reshape((-1,1))

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x_train,y_train)

# %%
accuracy=model.score(x_train,y_train)
accuracy
# Out:
# 0.9989431825295975

# %%
y_pred=model.intercept_+model.coef_*x_test

# %%
from sklearn.metrics import mean_squared_error,r2_score
y_train_prediction = model.predict(x_train)
y_test_prediction = model.predict(x_test)

# %%
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")
rmse_training = (np.sqrt(mean_squared_error(y_train, y_train_prediction)))
r2_training = r2_score(y_train, y_train_prediction)
print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse_training))
print('R2 score is {}'.format(r2_training))
print("\n")
rmse_testing = (np.sqrt(mean_squared_error(y_test, y_test_prediction)))
r2_testing = r2_score(y_test, y_test_prediction)
print("The model performance for testing set")
print("--------------------------------------")
print('Root mean squared error: ', rmse_testing)
print('R2 score: ', r2_testing)
# Out:
# Slope: [[1.35888668]]
# Intercept: [7.08080945e+08]
#
#
# The model performance for training set
# --------------------------------------
# RMSE is 14833322068.608109
# R2 score is 0.9989431825295976
#
#
# The model performance for testing set
# --------------------------------------
# Root mean squared error:  1353697721838.4119
# R2 score:  0.17639567646900078

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)

# %%
x_train=x_train.values.reshape((-1,1))
y_train=y_train.values.reshape((-1,1))
x_test=x_test.values.reshape((-1,1))

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x_train,y_train)

# %%
accuracy=model.score(x_train,y_train)
accuracy
# Out:
# 0.3328918785170156

# %%
y_pred=model.intercept_+model.coef_*x_test

# %%
from sklearn.metrics import mean_squared_error,r2_score
y_train_prediction = model.predict(x_train)
y_test_prediction = model.predict(x_test)

# %%
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")
rmse_training = (np.sqrt(mean_squared_error(y_train, y_train_prediction)))
r2_training = r2_score(y_train, y_train_prediction)
print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse_training))
print('R2 score is {}'.format(r2_training))
print("\n")
rmse_testing = (np.sqrt(mean_squared_error(y_test, y_test_prediction)))
r2_testing = r2_score(y_test, y_test_prediction)
print("The model performance for testing set")
print("--------------------------------------")
print('Root mean squared error: ', rmse_testing)
print('R2 score: ', r2_testing)
# Out:
# Slope: [[2.33653699]]
# Intercept: [8.54885425e+10]
#
#
# The model performance for training set
# --------------------------------------
# RMSE is 996709107577.7407
# R2 score is 0.3328918785170156
#
#
# The model performance for testing set
# --------------------------------------
# Root mean squared error:  108081705515.02397
# R2 score:  -8.024444918301334

# %%
X = crypto_data[["last_updated", "24h_volume_usd"]]
y = crypto_data["market_cap_usd"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.4, random_state=1)

# %%
from sklearn import linear_model as lm
import statsmodels.api as sm
model1 = sm.OLS(y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         market_cap_usd   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     1327.
# Date:                Fri, 21 Jun 2019   Prob (F-statistic):           9.13e-59
# Time:                        16:07:19   Log-Likelihood:                -2427.5
# No. Observations:                 100   AIC:                             4859.
# Df Residuals:                      98   BIC:                             4864.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
features = X_train.iloc[:,:].values

# %%
labels = y_train.iloc[:].values

# %%
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
predictions = model.predict(X)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.9489942808992177

# %%
#Visualize the predictions
import matplotlib.pyplot as plt
plt.scatter(y, predictions)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [-3.31251011e+08  1.33079823e+01]
# Intercept: 5.0192168519305683e+17
#
#
# The model performance
# --------------------------------------
# RMSE is 8885157579.14853
# R2 score is 0.9489942808992177

# %%
X = crypto_data[["24h_volume_usd", "price_btc","price_usd"]]
y = crypto_data["market_cap_usd"]
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
model1 = sm.OLS(y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         market_cap_usd   R-squared:                    -873.867
# Model:                            OLS   Adj. R-squared:               -900.925
# Method:                 Least Squares   F-statistic:                    -32.30
# Date:                Fri, 21 Jun 2019   Prob (F-statistic):               1.00
# Time:                        16:07:28   Log-Likelihood:                -2420.3
# No. Observations:                 100   AIC:                             4847.
# Df Residuals:                      97   BIC:                             4854.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.1, random_state=1)

# %%
features = X_train.iloc[:,:].values

# %%
labels = y_train.iloc[:].values

# %%
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
predictions = model.predict(X)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.9608081695987588

# %%
from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [ 1.66671857e+01  6.63943767e+12 -3.96028105e+08]
# Intercept: -459896116.96338844
#
#
# The model performance
# --------------------------------------
# RMSE is 6699420379.445019
# R2 score is 0.9608081695987588

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.2, random_state=1)

# %%
#features = X_train.iloc[:,:].values

# %%
#labels = y_train.iloc[:].values

# %%
X=features
y=labels
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
predictions = model.predict(X)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.9608081695987588

# %%
from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [ 1.66671857e+01  6.63943767e+12 -3.96028105e+08]
# Intercept: -459896116.96338844
#
#
# The model performance
# --------------------------------------
# RMSE is 6699420379.445019
# R2 score is 0.9608081695987588

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.4, random_state=1)

# %%
#features = X_train.iloc[:,:].values

# %%
#labels = y_train.iloc[:].values

# %%
'''X=features
y=labels'''
# Out:
# 'X=features\ny=labels'

# %%
'''from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)'''
# Out:
# 'from sklearn import linear_model as lm\nmodel=lm.LinearRegression()\nresults=model.fit(X,y)'

# %%
#predictions = model.predict(X)

# %%
'''accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)'''
# Out:
# "accuracy=model.score(X,y)\nprint('Accuracy of the model:', accuracy)"

# %%
'''from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")'''
# Out:
# 'from sklearn.metrics import mean_squared_error, r2_score\n\n# printing values\nprint(\'Slope:\' ,model.coef_)\nprint(\'Intercept:\', model.intercept_)\nprint("\n")\n\n\nimport numpy as np\nrmse = (np.sqrt(mean_squared_error(y,predictions)))\nr2 = r2_score(y,predictions)\n\nprint("The model performance")\nprint("--------------------------------------")\nprint(\'RMSE is {}\'.format(rmse))\nprint(\'R2 score is {}\'.format(r2))\nprint("\n")'

# %%
X = crypto_data[["24h_volume_usd", "available_supply","price_usd"]]
y = crypto_data["total_supply"]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
model1 = sm.OLS(y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           total_supply   R-squared:               -11968206.977
# Model:                            OLS   Adj. R-squared:          -12338357.739
# Method:                 Least Squares   F-statistic:                    -32.33
# Date:                Fri, 21 Jun 2019   Prob (F-statistic):               1.00
# Time:                        16:08:08   Log-Likelihood:                -2890.7
# No. Observations:                 100   AIC:                             5787.
# Df Residuals:                      97   BIC:                             5795.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.45, random_state=1)

# %%
features = X_train.iloc[:,:].values

# %%
labels = y_train.iloc[:].values

# %%
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
predictions = model.predict(X)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.9991205082104346

# %%
from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [ 6.77105043e+00  1.35888633e+00 -8.62122483e+06]
# Intercept: -594309659.0901031
#
#
# The model performance
# --------------------------------------
# RMSE is 13531761328.967817
# R2 score is 0.9991205082104347

# %%
X = crypto_data[["24h_volume_usd", "available_supply","percent_change_1h"]]
y = crypto_data["total_supply"]

# %%
model1 = sm.OLS(y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           total_supply   R-squared:               -11531836.848
# Model:                            OLS   Adj. R-squared:          -11888491.626
# Method:                 Least Squares   F-statistic:                    -32.33
# Date:                Fri, 21 Jun 2019   Prob (F-statistic):               1.00
# Time:                        16:08:29   Log-Likelihood:                -2888.8
# No. Observations:                 100   AIC:                             5784.
# Df Residuals:                      97   BIC:                             5791.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.45, random_state=1)

# %%
features = X_train.iloc[:,:].values
labels = y_train.iloc[:].values

# %%
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
predictions = model.predict(X)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.99905181453034

# %%
from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [6.16898565e-01 1.36048759e+00 1.90462887e+09]
# Intercept: -94863920.4343872
#
#
# The model performance
# --------------------------------------
# RMSE is 14050283337.54608
# R2 score is 0.99905181453034

# %%
X = crypto_data[["24h_volume_usd", "available_supply","percent_change_24h"]]
y = crypto_data["total_supply"]

# %%
model1 = sm.OLS(y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           total_supply   R-squared:               -11163063.728
# Model:                            OLS   Adj. R-squared:          -11508313.153
# Method:                 Least Squares   F-statistic:                    -32.33
# Date:                Fri, 21 Jun 2019   Prob (F-statistic):               1.00
# Time:                        16:08:44   Log-Likelihood:                -2887.2
# No. Observations:                 100   AIC:                             5780.
# Df Residuals:                      97   BIC:                             5788.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.45, random_state=1)

# %%
features = X_train.iloc[:,:].values
labels = y_train.iloc[:].values

# %%
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
predictions = model.predict(X)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.9989715498215418

# %%
from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [ 5.38433931e-01  1.36409344e+00 -6.30329170e+07]
# Intercept: 752888865.753479
#
#
# The model performance
# --------------------------------------
# RMSE is 14632888499.92048
# R2 score is 0.9989715498215418

# %%
X = crypto_data[["percent_change_1h", "available_supply"]]
y = crypto_data["total_supply"]
import statsmodels.api as sm
model1 = sm.OLS(y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           total_supply   R-squared:               -11531861.477
# Model:                            OLS   Adj. R-squared:          -11767205.609
# Method:                 Least Squares   F-statistic:                    -49.00
# Date:                Fri, 21 Jun 2019   Prob (F-statistic):               1.00
# Time:                        16:08:49   Log-Likelihood:                -2888.8
# No. Observations:                 100   AIC:                             5782.
# Df Residuals:                      98   BIC:                             5787.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.45, random_state=1)

# %%
features = X_train.iloc[:,:].values

# %%
labels = y_train.iloc[:].values

# %%
X=features
y=labels
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
predictions = model.predict(X)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.999035134383418

# %%
plt.scatter(y, predictions)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [1.87110534e+09 1.36029817e+00]
# Intercept: 371302120.6924286
#
#
# The model performance
# --------------------------------------
# RMSE is 14173328388.83562
# R2 score is 0.999035134383418

# %%
X = crypto_data[["percent_change_1h","price_btc"]]
y = crypto_data["total_supply"]
import statsmodels.api as sm
model1 = sm.OLS(y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           total_supply   R-squared:               -17996769.259
# Model:                            OLS   Adj. R-squared:          -18364050.284
# Method:                 Least Squares   F-statistic:                    -49.00
# Date:                Fri, 21 Jun 2019   Prob (F-statistic):               1.00
# Time:                        16:09:00   Log-Likelihood:                -2911.1
# No. Observations:                 100   AIC:                             5826.
# Df Residuals:                      98   BIC:                             5831.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.4, random_state=1)

# %%
features = X_train.iloc[:,:].values

# %%
labels = y_train.iloc[:].values

# %%
X=features
y=labels
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
predictions = model.predict(X)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.0014967342151674945

# %%
plt.scatter(y, predictions)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [-2.42134914e+09 -1.41000465e+11]
# Intercept: 104101613636.29529
#
#
# The model performance
# --------------------------------------
# RMSE is 492139229818.66833
# R2 score is 0.0014967342151674945

# %%
'''x=crypto_data['24h_volume_usd'] #x_train
y=crypto_data['market_cap_usd'] #y_trainfrom sklearn.model_selection import train_test_split  #train_test_split splits arrays or matrices into random train and test subsets. 
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.25,random_state=1) '''

# %%
#features = x_train.iloc[:,:].values

# %%
#labels = y_train.iloc[:].values

# %%
'''x=features
y=labels
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x,y) '''
# Out:
# 'x=features\ny=labels\nfrom sklearn import linear_model as lm\nmodel=lm.LinearRegression()\nresults=model.fit(x,y) '

# %%
#predictions = model.predict(X)

# %%
#accuracy=model.score(X,y)
#print('Accuracy of the model:', accuracy)

# %%
#plt.scatter(y, predictions)

# %%
'''from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")'''
# Out:
# 'from sklearn.metrics import mean_squared_error, r2_score\n\n# printing values\nprint(\'Slope:\' ,model.coef_)\nprint(\'Intercept:\', model.intercept_)\nprint("\n")\n\n\nimport numpy as np\nrmse = (np.sqrt(mean_squared_error(y,predictions)))\nr2 = r2_score(y,predictions)\n\nprint("The model performance")\nprint("--------------------------------------")\nprint(\'RMSE is {}\'.format(rmse))\nprint(\'R2 score is {}\'.format(r2))\nprint("\n")'

# %%
X = crypto_data[["24h_volume_usd", "available_supply","price_usd","price_btc"]]
y = crypto_data["market_cap_usd"]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.2, random_state=1)

# %%
features = X_train.iloc[:,:].values

# %%
labels = y_train.iloc[:].values

# %%
X=features
y=labels
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
predictions = model.predict(X)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.960977049653007

# %%
plt.scatter(y, predictions)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [ 1.66863635e+01  2.04789247e-04 -3.97704413e+08  6.66742573e+12]
# Intercept: -418103956.03158
#
#
# The model performance
# --------------------------------------
# RMSE is 7071111098.42675
# R2 score is 0.960977049653007
